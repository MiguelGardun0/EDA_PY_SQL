# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
import os
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine

load_dotenv()

user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST", "localhost")
port = os.getenv("DB_PORT", "5432")
db = os.getenv("DB_NAME")

engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}")

df = pd.read_sql("SELECT * FROM vegas LIMIT 5;", engine)

df.head()
# Out:
#   user_country  nr_reviews  nr_hotel_revies  helpful_votes  score  \
# 0          USA         372               78            169      4
# 1          USA          11                4             13      5
# 2          USA         119               21             75      3
# 3          USA          36                9             25      5
# 4           UK          14                7             14      4
#
#   period_of_stay traveler_type pool  gym tennis_court spa casino  \
# 0        Dec-Feb      Business  YES  YES           NO  NO    YES
# 1        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 2        Dec-Feb      Business   NO  YES           NO  NO    YES
# 3        Mar-May      Families   NO  YES           NO  NO    YES
# 4        Mar-May       Friends   NO  YES           NO  NO    YES
#
#   free_internet                              hotel_name  hotel_stars  \
# 0           YES                Marriott's Grand Chateau          3.5
# 1           YES  Circus Circus Hotel & Casino Las Vegas          3.0
# 2           YES  Circus Circus Hotel & Casino Las Vegas          3.0
# 3           YES  Circus Circus Hotel & Casino Las Vegas          3.0
# 4           YES  Circus Circus Hotel & Casino Las Vegas          3.0
#
#    nr_rooms user_continent  member_years review_month reviw_weekday
# 0       732  North America             4      January        Sunday
# 1      3773  North America             9      January      Thursday
# 2      3773  North America             3      January        Friday
# 3      3773  North America             2     February      Saturday
# 4      3773         Europe             6     February        Friday
